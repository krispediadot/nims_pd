# %% [markdown]
# ----
# ### Task
#
# 정상인과 파킨슨 환자의 보행 특징을 잘 나타내는 특징이 무엇인지?<br><br>
#
# ---
# ### Data
#
# 1. 보행 시 39개 마커의 위치 데이터
#     - 3차원 정보(x,y,z)
#     - 100Hz로 측정된 데이터
#     - 4m 보행
#     - Control-22명 / PD-81명
#     - 각 사람에 대한 FW(전방보행)/ BW(후방보행) trial - 쵀대 3번씩
#     - (주의) BW 데이터가 없는 사람이 있음.

# %% [markdown]
# <div>
# <img src="attachment:afae912b-9885-4482-bd05-1cf3e2bd0b66.png" width="500">
# </div>

# %% [markdown]
# <div>
# <img src="attachment:0576e09a-e5be-4180-bf2c-797f7e489d11.png" width="300">
# </div>

# %% [markdown]
# 2. 환자의 특성 정보
#     - 나이, 몸무게, 파킨슨 병의 진행 정도에 관련된 정보
#     - (주의) 해당 데이터가 없는 환자가 있음.
#     - (주의) 데이터셋과 이니셜이 매칭되지 않고 있음.

# %% [markdown]
# ----
# ### 진행 내용
#
# 1) <mark>LHEE 기준 RHEE 위가 시작점-frame 맞춤 - phase 나눔</mark><br>
#     dataset_LHEE_RHEE_Z_PHASE.ipynb<br><br>

# %% [markdown]
# <div>
# <img src="attachment:f5627f1e-1ae2-401b-bef3-573a6e2d206b.png" width="700">
# </div>

# %% [markdown]
# - 기울기<br>
# ![image.png](attachment:43f12cc8-79cb-4fbb-8de9-a741aba7ec3c.png)

# %% [markdown]
# - Z-axis<br>
# ![image.png](attachment:3193ad78-318d-4c51-928d-6fe04ad5942d.png)

# %% [markdown]
# 2) <mark>LHEE 기준으로 값 이동</mark><br>
#     dataset_LHEE_RHEE_Z_PHASE_STD.ipynb<br><br>

# %% [markdown]
# 3) <mark>z축 왼발 오른발 겹처보이기 (값, 변화)</mark><br>
#     3-1) <mark>넓이 계산해서 비교해보기</mark><br>
#         - Controls<br>
#             mean: 360.3548608730155<br>
#             std: 1565.5728372941462<br>
#         - PD<br>
#             mean: 142.97332588461543<br>
#             std: 1830.5223180195273<br>

# %% [markdown]
# 4) <mark>x-y 평면에 좌표 찍어서 보기<br><br></mark>
#     - Controls<br>
#     dataset_LHEE_RHEE_Z_PHASE_STD_reulst.ipynb
#     - PD<br>
#     dataset_LHEE_RHEE_Z_PHASE_STD_reulst_pd.ipynb

# %% [markdown]
# -----
# ### 지난 세미나 중 나온 의견
#
# 1. 윤현진 박사님의 의견<br>
#     파킨슨 환자에게 발생하는 보행 문제의 종류를 먼저 파악하는제 중요할 것 같다.<br>
#     1) 대칭성이 깨지는 문제가 발생하는지?<br>
#     2) 불규칙성이 깨지는 문제가 발생하는지?<br>
#
#     절대 좌표/ motion/ speed<br>
#     <br>
# 1. 팀장님의 의견<br>
#     L1 norm 면적의 차이를 비교해보기. 값으로 clustering을 해봄.<br>
#     각 페어가 있는 부분을 3차원으로 보는게 좋을듯.<br>

# %% [markdown]
# ---
# ### 오늘 세미나 중 나온 의견
#
# 1. 팀장님의 의견<br>
#     HEE를 기준으로 환자들이 clustering이 되는거 아닌가?
#     통계적 수치 외 clutering을 직접 해 볼것.
