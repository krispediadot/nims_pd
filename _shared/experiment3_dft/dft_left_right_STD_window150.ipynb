# %%
# 39개 마커
MARKERS = ['LFHD', 'RFHD', 'LBHD', 'RBHD', 'C7', 'LSHO', 'RSHO', 'CLAV', 'RBAK',
           'LUPA', 'RUPA', 'STRN', 'T10', 'LELB', 'RELB', 'LFRM', 'RFRM',
           'LWRA', 'RWRA', 'LWRB', 'RWRB', 'LFIN', 'RFIN', 'LASI', 'RASI',
           'LPSI', 'RPSI', 'LTHI', 'RTHI', 'LKNE', 'RKNE', 'LTIB', 'RTIB',
           'LANK', 'RANK', 'LTOE', 'RTOE', 'LHEE', 'RHEE']
len(MARKERS)
# Out:
# 39

# %%
MARKERS_PAIR = set([ m[1:] for m in MARKERS if m[0] == 'L' or m[0] == 'R' ])

# %%
import os
import glob

import pandas as pd
import numpy as np
from scipy.linalg import dft

import matplotlib.pyplot as plt

# %%
DATAPATH = "/Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD"
CONTROL = os.path.join(DATAPATH, "Controls")
PD = os.path.join(DATAPATH, "PD")

# df_patients = pd.read_csv(os.path.join(DATAPATH, "patients.csv"))
# df_null_info = pd.read_csv(os.path.join(DATAPATH, "NULL_info.csv"))
# df_csvinfo = pd.read_csv(os.path.join(DATAPATH, "csvinfo.csv"))

# %%
SAVEPATH = "/Users/sujinlee/Desktop/nims/pd/experiment3_dft"
SAVEFOLDER = os.path.join(SAVEPATH, "results_")

if os.path.exists(SAVEPATH) == False: os.makdir(SAVEPATH)
if os.path.exists(SAVEFOLDER) == False: os.mkdir(SAVEFOLDER)

# %%
def DFT(x):
    N = len(x)
    n = np.arange(N)
    k = n.reshape((N, 1))
    e = np.exp(-2j * np.pi * k * n / N)
    
    X = np.dot(e, x)
    
    return X

# %%
df0 = pd.read_csv(os.path.join(PD, os.listdir(PD)[0]))

# %%
df0.head()
# Out:
#    Frame  Sub Frame     LFHD_X     LFHD_Y       LFHD_Z     RFHD_X     RFHD_Y  \
# 0    465          0 -26.593998 -52.250732  1415.682187  93.093430 -53.191284
# 1    466          0 -27.887154 -42.230102  1414.885067  91.775978 -43.365478
# 2    467          0 -29.230495 -32.155273  1414.296811  90.402466 -33.495971
# 3    468          0 -30.629456 -22.034423  1413.946469  88.974762 -23.585571
# 4    469          0 -32.084473 -11.875854  1413.848935  87.499130 -13.640380
#
#         RFHD_Z     LBHD_X      LBHD_Y  ...    RTOE_Z  CentreOfMass_X  \
# 0  1408.825619 -30.274578 -203.833496  ... -6.930452       32.368675
# 1  1407.859066 -31.902618 -193.728637  ... -6.962865       31.490170
# 2  1407.088437 -33.606056 -183.548706  ... -6.979265       30.570805
# 3  1406.555111 -35.374718 -173.298584  ... -6.972660       29.614188
# 4  1406.288632 -37.196125 -162.987426  ... -6.937872       28.627365
#
#    CentreOfMass_Y  CentreOfMass_Z  CentreOfMassFloor_X  CentreOfMassFloor_Y  \
# 0     -120.042114      800.641110            32.368675          -120.042114
# 1     -110.495117      799.904355            31.490170          -110.495117
# 2     -100.940307      799.305783            30.570805          -100.940307
# 3      -91.368774      798.880673            29.614188           -91.368774
# 4      -81.769165      798.655636            28.627365           -81.769165
#
#    CentreOfMassFloor_Z  LHEE_Z_DIFF  RHEE_Z_DIFF  PHASE
# 0           -23.969791     0.162809     3.779896    1.0
# 1           -23.969791     0.314476     4.260330    1.0
# 2           -23.969791     0.432141     4.815636    1.0
# 3           -23.969791     0.511118     5.449150    1.0
# 4           -23.969791     0.550525     6.154419    1.0
#
# [5 rows x 128 columns]

# %%
df0 = pd.read_csv(os.path.join(PD, os.listdir(PD)[10]))
plt.plot(df0["LHEE_Z"])
plt.show()

# %%
sr = 100

x = df0["LHEE_Z"]
X = DFT(x)

N = len(X)
n = np.arange(N)
T = N/sr
freq = n/T 

print("sampling rate:", sr)
print("N:", N)
# print("n:", n)
# print("T:", T)
# print("freq:", freq)

plt.figure(figsize = (8, 6))
plt.stem(freq, abs(X), 'b', \
         markerfmt=" ", basefmt="-b")
plt.xlabel('Freq (Hz)')
plt.ylabel('DFT Amplitude |X(freq)|')
plt.show()
# Out:
# sampling rate: 100
# N: 736

# %%
n_oneside = N//2
# get the one side frequency
f_oneside = freq[:n_oneside]

# normalize the amplitude
X_oneside =X[:n_oneside]/n_oneside

plt.figure(figsize = (12, 6))
plt.subplot(121)
plt.stem(f_oneside, abs(X_oneside), 'b', \
         markerfmt=" ", basefmt="-b")
plt.xlabel('Freq (Hz)')
plt.ylabel('DFT Amplitude |X(freq)|')

plt.subplot(122)
plt.stem(f_oneside, abs(X_oneside), 'b', \
         markerfmt=" ", basefmt="-b")
plt.xlabel('Freq (Hz)')
plt.xlim(0, 10)
plt.tight_layout()
plt.show()

# %%
for idx in np.argsort(abs(X_oneside))[::-1]:
    if f_oneside[idx] != 0:
        print("         freq:", f_oneside[idx])
        print("DFT amplitude:", abs(X_oneside)[idx])
        break
# Out:
#          freq: 0.6793478260869565
# DFT amplitude: 26.250635310442533

# %%
def get_result(df_sub, TARGET_MARKER_LR):
    x = df_sub[f"{TARGET_MARKER_LR}_Z"]
    X = DFT(x)

    N = len(X)
    n = np.arange(N)
    T = N/sr
    freq = n/T 
    
    n_oneside = N//2
    # get the one side frequency
    f_oneside = freq[:n_oneside]

    # normalize the amplitude
    X_oneside =X[:n_oneside]/n_oneside
    
    result_idx = -1;

    for idx in np.argsort(abs(X_oneside))[::-1]:
        if f_oneside[idx] != 0:
            result_idx = idx
#             print("         freq:", f_oneside[idx])
#             print("DFT amplitude:", abs(X_oneside)[idx])
            break
        
    return f_oneside[result_idx].copy(), X_oneside[result_idx].copy()

# %%
def dft_left_right(TARGET_CATE, TARGET_MOTION, TARGET_MARKER, WINDOW_SIZE, debug=True):
    results = []
    left_freq = []
    left_amp = []
    right_freq = []
    right_amp = []

    for csv_file in glob.glob(os.path.join(TARGET_CATE, f"*{TARGET_MOTION}*.csv")):
#         print(csv_file)
        df = pd.read_csv(os.path.join(TARGET_CATE, csv_file))
        df = df.dropna()

        if len(df) < WINDOW_SIZE: continue 

        df_sub = df.copy()
    #     print(csv_file, '|', len(df_sub))

        freq_left, amp_left = get_result(df_sub, f"L{TARGET_MARKER}")
        freq_right, amp_right = get_result(df_sub, f"R{TARGET_MARKER}")

        info = {"filename": csv_file,
                "length": len(df_sub),
                "freq_left": freq_left,
                "amp_left": amp_left,
                "freq_right": freq_right,
                "amp_right": amp_right,
               }
    #     print(info)
        left_freq.append(freq_left)
        left_amp.append(amp_left)
        right_freq.append(freq_right)
        right_amp.append(amp_right)

        results.append(info)
        
    if debug:
        print("Category:", TARGET_CATE)
        print("Motion:", TARGET_MOTION)
        print("Marker:", TARGET_MARKER)
    #     print("Window:", WINDOW_SIZE)
        print("Count:", len(results))
    #     print("Mean: ", np.mean(np.array(inner_product)))
    #     print("Std: ", np.std(np.array(inner_product)))

    #     plt.scatter(range(0, len(inner_product)), inner_product)
    #     plt.xlabel("Files")
    #     plt.ylabel("Inner product")
    #     plt.title("left & right inner product")
    #     plt.show()

    #     plt.hist(inner_product)
    #     plt.xlabel("Inner product")
    #     plt.ylabel("Count")
    #     plt.title("left & right inner product histogram")
    #     plt.show()

    return results, left_freq, left_amp, right_freq, right_amp

# %%
def run(TARGET_MOTION, TARGET_MARKER, WINDOW_SIZE, debug=True):
    
    pd_results, pd_left_freq, pd_left_amp, pd_right_freq, pd_right_amp = dft_left_right(TARGET_CATE=PD, TARGET_MOTION=TARGET_MOTION, TARGET_MARKER=TARGET_MARKER, WINDOW_SIZE=WINDOW_SIZE)
    control_results, control_left_freq, control_left_amp, control_right_freq, control_right_amp = dft_left_right(TARGET_CATE=CONTROL, TARGET_MOTION=TARGET_MOTION, TARGET_MARKER=TARGET_MARKER, WINDOW_SIZE=WINDOW_SIZE)

    if debug:
        print("------")
        print("Category: PD")
        print()
        print("LEFT Mean: ", np.mean(pd_left_freq))
        print("LEFT Std: ", np.std(pd_left_freq))
        print()
        print("RIGHT Mean: ", np.mean(pd_right_freq))
        print("RIGHT Std: ", np.std(pd_right_freq))

    fig, axes = plt.subplots(1, 2, figsize=(10, 5))

    axes[0].hist(pd_left_freq)
    axes[0].set_xlim([0, 3])
    axes[0].set_xlabel("Freq")
    axes[0].set_ylabel("Count")
    axes[0].set_title(f"PD - L{TARGET_MARKER}")
    # plt.show()

    axes[1].hist(pd_right_freq)
    axes[1].set_xlim([0, 3])
    axes[1].set_xlabel("Freq")
    axes[1].set_ylabel("Count")
    axes[1].set_title(f"PD - R{TARGET_MARKER}")
    plt.show()

    if debug:
        print()
        print("Category: Control")
        print()
        print("LEFT Mean: ", np.mean(control_left_freq))
        print("LEFT Std: ", np.std(control_left_freq))
        print()
        print("RIGHT Mean: ", np.mean(control_right_freq))
        print("RIGHT Std: ", np.std(control_right_freq))

    fig, axes = plt.subplots(1, 2, figsize=(10, 5))

    axes[0].hist(control_left_freq)
    axes[0].set_xlim([0, 3])
    axes[0].set_xlabel("Freq")
    axes[0].set_ylabel("Count")
    axes[0].set_title(f"Control - L{TARGET_MARKER}")
    # plt.show()

    axes[1].hist(control_right_freq)
    axes[1].set_xlim([0, 3])
    axes[1].set_xlabel("Freq")
    axes[1].set_ylabel("Count")
    axes[1].set_title(f"Control - R{TARGET_MARKER}")
    plt.show()

# %%
print(len(glob.glob(os.path.join(PD, f"*{TARGET_MOTION}*.csv"))))
print(len(glob.glob(os.path.join(CONTROL, f"*{TARGET_MOTION}*.csv"))))
# Out:
# 229
# 63

# %%
# run

TARGET_MOTION = "FW"
TARGET_MARKER = "HEE"
WINDOW_SIZE = 150

run(TARGET_MOTION, TARGET_MARKER, WINDOW_SIZE)
# Out:
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: HEE
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: HEE
# Count: 39
# ------
# Category: PD
#
# LEFT Mean:  0.9267669538433552
# LEFT Std:  0.1795581049467875
#
# RIGHT Mean:  0.9813423788828638
# RIGHT Std:  0.24582565381687327
# Category: Control
#
# LEFT Mean:  0.839910082180262
# LEFT Std:  0.2850934883744406
#
# RIGHT Mean:  0.8494067583436049
# RIGHT Std:  0.2710025945144223

# %%
TARGET_MOTION = "FW"
WINDOW_SIZE = 150

print(len(glob.glob(os.path.join(CONTROL, f"*{TARGET_MOTION}*.csv"))))
print(len(glob.glob(os.path.join(PD, f"*{TARGET_MOTION}*.csv"))))

for TARGET_MARKER in MARKERS_PAIR:
    print()
    print("TARGET MARKER:", TARGET_MARKER)

    try:
        run(TARGET_MOTION, TARGET_MARKER, WINDOW_SIZE, debug=False)
    except:
        pass
# Out:
# 63
# 229
#
# TARGET MARKER: KNE
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: KNE
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: KNE
# Count: 39
# TARGET MARKER: FIN
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: FIN
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: FIN
# Count: 39
# TARGET MARKER: FHD
#
# TARGET MARKER: UPA
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: UPA
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: UPA
# Count: 39
# TARGET MARKER: ELB
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: ELB
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: ELB
# Count: 39
# TARGET MARKER: BHD
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: BHD
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: BHD
# Count: 39
# TARGET MARKER: ASI
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: ASI
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: ASI
# Count: 39
# TARGET MARKER: THI
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: THI
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: THI
# Count: 39
# TARGET MARKER: PSI
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: PSI
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: PSI
# Count: 39
# TARGET MARKER: WRB
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: WRB
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: WRB
# Count: 39
# TARGET MARKER: ANK
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: ANK
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: ANK
# Count: 39
# TARGET MARKER: BAK
#
# TARGET MARKER: TOE
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: TOE
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: TOE
# Count: 39
# TARGET MARKER: HEE
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: HEE
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: HEE
# Count: 39
# TARGET MARKER: WRA
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: WRA
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: WRA
# Count: 39
# TARGET MARKER: TIB
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: TIB
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: TIB
# Count: 39
# TARGET MARKER: FRM
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: FRM
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: FRM
# Count: 39
# TARGET MARKER: SHO
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/PD
# Motion: FW
# Marker: SHO
# Count: 207
# Category: /Users/sujinlee/Desktop/nims/pd/dataset_LHEE_RHEE_Z_PHASE_STD/Controls
# Motion: FW
# Marker: SHO
# Count: 39
